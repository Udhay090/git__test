# %% [markdown]
# 1.oops
# 2.we create classes and objects
# '3.lets say we wanna store data with parameters(age,name,location) of 100 students it would be realy hard to do that
# 4.we can do this by creating a class of students.
# 5.

# %%
 class student:
       pass
     
 student1 = student( )
 student1.name="ishant"
 student1.age=20
 student1.marks=95
 print(student1.name)
 student2 = student( )
 student2.name="karan"
 student2.age=22
 student2.marks=85
 print(student2.name)#INSTEAD OF THIS WE CAN DO THIS

# %%
class  student:
     name =" "#attributes
     age= 0
     location=" "#data members are written within the class 
    
# student1 = student()
# # student1.age=2
# student1.name="udhay"
# print(student1.age)

n = int(input())
s1list=[ ]
for i in range(n):

     s1=student()
     s1.name=input()
     s1.age=int(input())
     s1.location= input( )
     s1list.append(s1)
     

for i in range(n):
    print(type(s1list[i]))
    print(s1list[i].name,s1list[i].age,s1list[i].location)
# Out:
# <class '__main__.student'>
# udhay 23 udhampur
