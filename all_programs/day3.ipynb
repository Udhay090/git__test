# %%
a=5#  = is assignment operator 
b=10# == is comparison operator
print(a==b)#equal to
print(a!=b)#not equal to
print(a>=b)#greater than or equal to
print(a<=b)#less than or equal to
print(a>b)#greater than
print(a<b)#less than
print(f"a={a}, b={b},a==b is", a==b)
# Out:
# False
# True
# False
# True
# False
# True
# a=5, b=10,a==b is False

# %%
#logical operators :and ,or,not
True and False
print("a={a}")
# Out:
# a={a}
