# %%
Acc_balance = 500 # Accbalance = variable name
print(Acc_balance)
# Out:
# 500

# %%
#concatenation of strings
first_name="john"
last_name="cena"
full_name= first_name + last_name
print(full_name)# dont write print("full_name")
hi= "Hi" + full_name +"!"
print(hi)
# Out:
# johncena
# Hijohncena!

# %%
name ="Manav"
score=5.5
result=name+" scored " +str(score) +" marks"
print(result)
# Out:
# Manav scored 5.5 marks

# %%
print("bye \t \t world")
print("\n age:20 \n name:udhay\n rollno: 90")
print(" a \\ b ")
# Out:
# bye 	 	 world
#
#  age:20
#  name:udhay
#  rollno: 90
#  a \ b

# %%
name="manav"
age=22
print(f"{name} is {age} yrs old")#fstring
# Out:
# manav is 22 yrs old

# %%
name= input("Name: ")
score=int(input("score: "))#typecasting
print(name)
print(score)
# Out:
# Name: john
# score: 22
# john
# 22
