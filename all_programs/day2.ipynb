# %%
#typecasting
var1=5.45# float to int
var1_int= int(var1)
print(var1_int)
print(type(var1_int))
# Out:
# 5
# <class 'int'>

# %%
var1=True#bool to int
var2=False
var1_int=int(var1)
var2_int=int(var2)
print(var1_int)
print(var2_int)
# Out:
# 1
# 0

# %%
number=int("123")
print(number)
print(f" '123'  is converted to : {number} ")
# Out:
# 123
#  '123'  is converted to : 123

# %%
#arithmetic operators
print(2+3)
print(5-2)
print(5*2)
print(7/2)
print(7//2)
print(3**3)
# Out:
# 5
# 3
# 10
# 3.5
# 3
# 27

# %%
#calculator
a=int(input("enter the integer a :"))
b=int(input("enter the integer b :"))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a**b)
# Out:
# enter the integer a :5
# enter the integer b :4
# 9
# 1
# 20
# 1.25
# 1
# 625

# %%
name=("udhay")
age= 20
cgpa=6.2
happy=True
print(f"name is : {name}")
print(f"age is : {age}")
print(f"cgpa is : {cgpa}")
print("name=",name)
print("age=",age)
print("cgpa=",cgpa)
print("type of name is:",type(name))
print("type of age is :",type(age))
print("type of cgpa is  :",type(cgpa))
# Out:
# name is : udhay
# age is : 20
# cgpa is : 6.2
# name= udhay
# age= 20
# cgpa= 6.2
# type of name is: <class 'str'>
# type of age is : <class 'int'>
# type of cgpa is  : <class 'float'>

# %%
String = ("python")
integer = 345
Float = 67.5
boolean = True
print(f"type of {String}  is : ",type(String) )
print(f"type of {integer} is: ",type(integer))
print(f"type of {Float} is: ", type(Float))
print(f"type of {boolean} is : ", type(boolean))
# Out:
# type of python  is :  <class 'str'>
# type of 345 is:  <class 'int'>
# type of 67.5 is:  <class 'float'>
# type of True is :  <class 'bool'>

# %%
#float to int
bank_balance=110.01
print(int(bank_balance))
print(f"bank balance_int is: ",int(bank_balance))
#string to int
money=("345")
money_int=int(money)
print("int value of money is :",money_int)
print(int(money))
#boolean to int
pasta=True
print(int(pasta))
# Out:
# 110
# bank balance_int is:  110
# int value of money is : 345
# 345
# 1

# %%
age="24"
print(int(age))
# Out:
# 24
